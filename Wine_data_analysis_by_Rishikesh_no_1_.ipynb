# %% [markdown]
# ## Load the library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Read the data

# %%
## Loading the data from your file or data source.

# %%
wine_df=pd.read_csv("/content/winequalityN.csv")

# %%
## Showing first 5 rows
wine_df.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# ...

# %%
## Show last 5 rows
wine_df.tail()
# Out:
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 6492  red            6.2             0.600         0.08             2.0
# 6493  red            5.9             0.550         0.10             2.2
# 6494  red            6.3             0.510         0.13             2.3
# 6495  red            5.9             0.645         0.12             2.0
# 6496  red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6493      0.062                 39.0                  51.0  0.99512  3.52
# 6494      0.076                 29.0                  40.0  0.99574  3.42
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6496      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol  quality
# 6492       0.58     10.5        5
# ...

# %%
## Show the info for data
wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6487 non-null   float64
#  2   volatile acidity      6489 non-null   float64
#  3   citric acid           6494 non-null   float64
#  4   residual sugar        6495 non-null   float64
#  5   chlorides             6495 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6488 non-null   float64
#  10  sulphates             6493 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
wine_df.shape
# Out:
# (6497, 13)

# %% [markdown]
# We have 13 columns and 497 rows available in dataset

# %%
## Show the columns
wine_df.columns
# Out:
# Index(['type', 'fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'],
#       dtype='object')

# %%
## Show the description summary for numerical and categorical values

# %%
wine_df.describe()   #description summery for numerical columns
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6487.000000       6489.000000  6494.000000     6495.000000
# mean        7.216579          0.339691     0.318722        5.444326
# std         1.296750          0.164649     0.145265        4.758125
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6495.000000          6497.000000           6497.000000  6497.000000
# mean      0.056042            30.525319            115.744574     0.994697
# std       0.035036            17.749400             56.521855     0.002999
# ...

# %% [markdown]
# Above analysis show the statstical analysis of the data ,for each column there are mean value, standerd daviation diffrent quantiles and maximum values for each column

# %%
wine_df.describe(include="O") #description summery for categorica columns
# Out:
#          type
# count    6497
# unique      2
# top     white
# freq     4898

# %%
numerical_columns=['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol', 'quality']

# %%
categorical_columns=['type']

# %%
wine_df.head(10)
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
# 5  white            8.1              0.28         0.40             6.9
# 6  white            6.2              0.32         0.16             7.0
# 7  white            7.0              0.27         0.36            20.7
# 8  white            6.3              0.30         0.34             1.6
# 9  white            8.1              0.22         0.43             1.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# ...

# %% [markdown]
# we have only one categorical column in this dataset,other all columns are numerical columns

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Do Numerical Analysis of Columns

# %%
#  Numerical column analysis

# %% [markdown]
# Numerical column analysis for fixed acidity

# %%
#  Maximum and mimimum value mean, meadian or std deviation or variance, skew

print(wine_df["fixed acidity"].max())
print(wine_df["fixed acidity"].min())
print(wine_df["fixed acidity"].mean())
print(wine_df["fixed acidity"].median())
print(wine_df["fixed acidity"].var())
print(wine_df["fixed acidity"].std())
# Out:
# 15.9
# 3.8
# 7.2165793124710955
# 7.0
# 1.6815601904014388
# 1.296749856526477

# %%
wine_df["fixed acidity"].skew()
# Out:
# 1.7228045308969795

# %%
#Histogram plot for column fixed acidity
plt.figure(figsize=(6,4))
sns.histplot(wine_df["fixed acidity"],bins=10)
plt.title("Histogram plot for fixed acidity",y=1.02)
plt.ylabel("frequency")
plt.show()

# %%
#Distribtion plot for column "fixed acidity"
plt.figure(figsize=(6,4))
sns.displot(x=wine_df["fixed acidity"],kde="kind")
plt.title("Distribution plot for fixed acidity",y=1.02)
# Out:
# Text(0.5, 1.02, 'Distribution plot for fixed acidity')

# %%
#Box plot to detect outliers
plt.figure(figsize=(6,4))
sns.boxplot(wine_df["fixed acidity"],orient="h") 
plt.title("Box plot for fixed acidity",y=1.02)
plt.xlabel("Fixed acidity")
plt.show()

# %%
wine_df["fixed acidity"].quantile(0.10),wine_df["fixed acidity"].quantile(0.25),wine_df["fixed acidity"].quantile(0.50),wine_df["fixed acidity"].quantile(0.75),wine_df["fixed acidity"].quantile(0.90)
# Out:
# (6.0, 6.4, 7.0, 7.7, 8.8)

# %% [markdown]
# *Obsevations
# *   column fixed acidity has maximum value 15.9 and minimum value is 3.8
# *   column fixed acidity has mean value 7.21 & median value is 7.
# *   column fixed acidity standerd daviation has 1.29 and variance has 1.68
# *   By histogram we can conclude that most of thw wine has fixed acidity lies b/w 6 to 8.
# *   Density curve for fixed acidity is centred around mean 7.21 with standard deviation of 1.29
# * 10% of wine has fixed acidity 6.0 and below.
# * 25% of wine has fixed acidity 6.4 and below.
# * 50% of wine has fixed acidity 7.0 and below.
# * 75% of wine has fixed acidity 7.7 and below.
# * 90% of wine has fixed acidity 8.8 and below.
# * Data has skew value which is 1.72 ,which is not lies b/w -0.5 and 0.5 that means data is skewed & right skewed in nature.

# %% [markdown]
# #Numerical column analysis for column residual sugar

# %%
print(wine_df["residual sugar"].max())
print(wine_df["residual sugar"].min())
print(wine_df["residual sugar"].mean())
print(wine_df["residual sugar"].median())
print(wine_df["residual sugar"].var())
print(wine_df["residual sugar"].std())
print(wine_df["residual sugar"].skew())
# Out:
# 65.8
# 0.6
# 5.444326404926867
# 3.0
# 22.639751066834243
# 4.7581247426727105
# 1.4349998392718966

# %%
#quantile analysis for colum residual sugar
wine_df["residual sugar"].quantile(0.10),wine_df["residual sugar"].quantile(0.25),wine_df["residual sugar"].quantile(0.50),wine_df["residual sugar"].quantile(0.75),wine_df["residual sugar"].quantile(0.90)
# Out:
# (1.3, 1.8, 3.0, 8.1, 13.0)

# %%
#Histogram plot for column residual sugar
plt.figure(figsize=(6,4))
sns.histplot(wine_df["residual sugar"],bins=10)
plt.title("Histogram plot for residual sugar",y=1.02)
plt.ylabel("frequency")
plt.show()

# %%
#Distribtion plot for column "residual sugar"
plt.figure(figsize=(6,4))
sns.displot(x=wine_df["residual sugar"],kind="kde")
plt.title("Distribution plot for residual sugar",y=1.02)
# Out:
# Text(0.5, 1.02, 'Distribution plot for residual sugar')

# %%
#Box plot to detect outliers
plt.figure(figsize=(6,4))
sns.boxplot(wine_df["residual sugar"],orient="h") 
plt.title("Box plot for residual sugar",y=1.02)
plt.xlabel("residual sugar")
plt.show()

# %% [markdown]
# *Obsevations
# *   column residual sugar has maximum value 65.8 for wine and minimum value is 0.6
# *   column residual sugar standerd daviation has 4.75 and variance has 22.63.
# *   By histogram we can conclude that most of thw wine has residual sugar lies b/w 6 to 8.
# *   Density curve for residual sugar is centred around mean 5.44 with standard deviation of 4.7
# *   So much outliers are available in data after residual sugar value 18.
# *   10% of wine has residual sugar 1.3 and below.
# *   25% of wine has residual sugar 1.8 and below.
# *   50% of wine has residual sugar 3.0 and below.
# *   75% of wine has residual sugar 8.1 and below.
# *   90% of wine has residual sugar 13.0 and below.
# -Data has skew value which is 1.43 ,which is not lies b/w -0.5 and 0.5 that means data is skewed & right skewed in nature

# %% [markdown]
# #Analysis of numerical column "total sulfur dioxide"

# %%
print(wine_df["total sulfur dioxide"].max())
print(wine_df["total sulfur dioxide"].min())
print(wine_df["total sulfur dioxide"].mean())
print(wine_df["total sulfur dioxide"].median())
print(wine_df["total sulfur dioxide"].var())
print(wine_df["total sulfur dioxide"].std())
print(wine_df["total sulfur dioxide"].skew())
# Out:
# 440.0
# 6.0
# 115.7445744189626
# 118.0
# 3194.720038677381
# 56.52185452263028
# -0.001177478234437964

# %%
wine_df["total sulfur dioxide"].quantile(0.10),wine_df["total sulfur dioxide"].quantile(0.25),wine_df["total sulfur dioxide"].quantile(0.50),wine_df["total sulfur dioxide"].quantile(0.75),wine_df["total sulfur dioxide"].quantile(0.90)
# Out:
# (30.0, 77.0, 118.0, 156.0, 188.0)

# %%
#Hstogram plot for column total sulfur dioxide
sns.histplot(wine_df["total sulfur dioxide"],bins=8)
# Out:
# <Axes: xlabel='total sulfur dioxide', ylabel='Count'>

# %%
#distribution plot for column total sulfur dioxide
sns.displot(x=wine_df["total sulfur dioxide"],kde="kind")
plt.title("distribution plot for total sulfur dioxide present in wine")
plt.show()

# %%
#Box plot for column total sulfur dioxide   to detect outliers
sns.boxplot(x=wine_df["total sulfur dioxide"],color="gold")
# Out:
# <Axes: xlabel='total sulfur dioxide'>

# %% [markdown]
# *Obsevations
# *   column total sulfur dioxide has maximum value 440 for wine and minimum value is 6
# *   column total sulfur dioxide standerd daviation has 56.52 and variance has 3194.72.
# *   By histogram we can conclude that most of the wine has total sulfur dioxide lies around 50 to 150.
# *   Density curve for total sulfur dioxide is centred around mean 115.74 with standard deviation of 56.52.
# *   So much outliers are available in data after total sulfur dioxide value around 280.
# *   10% of wine has total sulfur dioxide 30 and below.
# *   25% of wine has total sulfur dioxide 77 and below.
# *   50% of wine has total sulfur dioxide 118 and below.
# *   75% of wine has total sulfur dioxide 156 and below.
# *   90% of wine has total sulfur dioxide 188 and below.
# -Data has skew value which is -0.001,which is lies b/w -0.5 and 0.5 that means data is not skewed & making bell shape curve

# %% [markdown]
# #Analysis of numerical column alcohol

# %%
print(wine_df["alcohol"].max())
print(wine_df["alcohol"].min())
print(wine_df["alcohol"].mean())
print(wine_df["alcohol"].median())
print(wine_df["alcohol"].var())
print(wine_df["alcohol"].std())
print(wine_df["alcohol"].skew())
# Out:
# 14.9
# 8.0
# 10.491800831149455
# 10.3
# 1.4225613158901027
# 1.192711748868981
# 0.5657177290960251

# %%
wine_df["alcohol"].quantile(0.10),wine_df["alcohol"].quantile(0.25),wine_df["alcohol"].quantile(0.50),wine_df["alcohol"].quantile(0.75),wine_df["alcohol"].quantile(0.90)
# Out:
# (9.1, 9.5, 10.3, 11.3, 12.3)

# %%
#Histogram for coumn alcohol
sns.histplot(x=wine_df["alcohol"],bins=20)
# Out:
# <Axes: xlabel='alcohol', ylabel='Count'>

# %%
#Distribution plot for column alcohol
sns.displot(x=wine_df["alcohol"],kind="kde")

# %%
#vilionplot for column alcohol
plt.figure(figsize=(6,4))
sns.violinplot(x=wine_df["alcohol"],color="red")
plt.title("vilionplot for column alcohol")
plt.show()

# %%
#boxplot for column alcohol to detect outliers
plt.figure(figsize=(6,4))
sns.boxplot(wine_df["alcohol"],color="gold",orient="h")
plt.title("boxplot for column alcohol")
plt.show()

# %% [markdown]
# *Obsevations
# *   column alcohol has maximum value 14.9 for wine and minimum value is 8.0
# *   column alcohol standerd daviation has 1.19 and variance has 1.42.
# *   By histogram we can conclude that most of the wine has alcohol values present  b/w 9 to 10.
# *   Density curve for alcohol is centred around mean 10.49 with standard deviation of 1.19
# *   No outliers are available in data.
# *  10% of wine has alcohol content 9.1 and below.
# *   25% of wine has alcohol content 9.5 and below.
# *   50% of wine has alcohol content 10.3 and below.
# *   75% of wine has alcohol content 11.3 and below.
# *   90% of wine has alcohol content 12.3 and below.
# *  Data has skew value which is 0.56 ,which is lies b/w -0.5 and 0.5 that means data is not skewed.

# %% [markdown]
# #Column analysis"Quality"

# %%
wine_df["quality"].value_counts().sort_values()
# Out:
# 9       5
# 3      30
# 8     193
# 4     216
# 7    1079
# 5    2138
# 6    2836
# Name: quality, dtype: int64

# %%
wine_df['quality'].value_counts(normalize=True)*100
# Out:
# 6    43.650916
# 5    32.907496
# 7    16.607665
# 4     3.324611
# 8     2.970602
# 3     0.461752
# 9     0.076959
# Name: quality, dtype: float64

# %%
plt.figure(figsize=(8,6))
sns.countplot(x=wine_df["quality"])
plt.title("Count plot for quality",y=1.02)
#plt.xlabel("")
# plt.ylabel("")
plt.show()

# %% [markdown]
# Observations
# *   from above analysis we can conclude that quality level 6 has 2,836 wines available around 43.65
# *   While quality level 9 has lowest only 5 nos wines are present in data.

# %% [markdown]
# ## Do Categortical  Analysis of Columns

# %% [markdown]
# #Categorical column analysis for column "Wine Type"

# %%
#how data shared in red & white wine 
wine_df["type"].value_counts()   #we count the values for type column
# Out:
# white    4898
# red      1599
# Name: type, dtype: int64

# %%
wine_df["type"].value_counts(normalize=True)*100#values count n percentage
# Out:
# white    75.388641
# red      24.611359
# Name: type, dtype: float64

# %%
#unique values column has
wine_df["type"].unique()
# Out:
# array(['white', 'red'], dtype=object)

# %%
#number of unique values the column has
wine_df["type"].nunique()
# Out:
# 2

# %%
#count plot for type
plt.figure(figsize=(4,2))
sns.countplot(x="type",data=wine_df)
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %%
plt.figure(figsize=(4,6))
sizes = [4898,1599]
plt.pie(sizes, labels=["white","red"], autopct='%1.2f%%')
plt.legend()
plt.show()

# %%
## Conclude and write down your observation.

# %% [markdown]
# *Obsevations
# *  Type columns has total 2 unique values
# *  The unique values are Red & White, which represents the type of wine
# *  In this date the white whine has count 4,898 & red has count 1599.
# *  Total 75.38% sharing in coulumn has type white wine, for redwine 24.61 only

# %% [markdown]
# ## Combine Numerical and categorical columns for analysis
#
# ---
#
#
#
# ---

# %% [markdown]
# #Analysis of columns type and alcohol

# %%
plt.figure(figsize=(6,4))
sns.barplot(data=wine_df,x="type",y="alcohol",errorbar=None)
plt.title("Bar plot for type & alcohol",y=1.02)
plt.xlabel("type")
plt.show()

# %% [markdown]
# Observations
# Kind of similer alcohel content by both type of wine

# %% [markdown]
# ###Analysis of columns "type" and "quality"

# %%
plt.figure(figsize=(6,4))
sns.barplot(data=wine_df,x="type",y="quality",errorbar=None)
plt.title("Bar plot for type & quality",y=1.02)
plt.xlabel("type")
plt.show()

# %% [markdown]
# Observations
# *   From above analysis we can conclude that white wine has slightly more good quality than red

# %% [markdown]
# ##Combine Numerical coluns for analysis

# %% [markdown]
# ###columns "quality" and "fixed acidity" analysis

# %%
#Bar lot for these columns quality and fixed acidity
plt.figure(figsize=(6,4))
sns.barplot(data=wine_df,x="quality",y="fixed acidity",errorbar=None)
plt.title("Bar plot for quality and fixed acidity in wine",y=1.02)
plt.xlabel("quality")
plt.show()

# %% [markdown]
# Observations
# *   From above analysis we not much get
# *   As at quality level 3 has same acids present as quality number 9

# %% [markdown]
# #Column analysis "quality" and "total slpher dioxide"

# %%
#Bar plot for these columns quality and total sulpher dioxide in wine
plt.figure(figsize=(6,4))
sns.barplot(data=wine_df,x="quality",y="total sulfur dioxide",errorbar=None)
plt.title("Bar plot for quality and total sulfur dioxide in wine",y=1.02)
plt.xlabel("quality")
plt.show()

# %% [markdown]
# Observations
# *   From above analysis we can conclude that all quality level of wine has similer kind of sulpher dioxide present in wine
# *   We can not much conclude from this observation

# %% [markdown]
# #Analysis of columns "quality' and "residual sugar" in wine

# %%
#Bar plot for these columns quality and residual sugar in wine
plt.figure(figsize=(6,4))
sns.barplot(data=wine_df,x="quality",y="residual sugar",errorbar=None)
plt.title("Bar plot for quality and residual sugar in wine",y=1.02)
plt.xlabel("quality")
plt.show()

# %% [markdown]
# Observations
# *   From above analysis we can able to see thatquality level 5 has maximum residual sugar present in wine
# *   But also from this analysis we can not find much as residual suger has no effect on quality of wine

# %% [markdown]
# ## Add your own Questions

# %% [markdown]
# ###Analysis of column "Type" and "chlorides"

# %%
#It will help to find which type of wine has more salt present

# %%
wine_df.groupby(["type"])["chlorides"].sum()
# Out:
# type
# red      139.859
# white    224.131
# Name: chlorides, dtype: float64

# %%
wine_df["chlorides"].sum()
# Out:
# 363.99

# %%
red_wine_clorides=139.859/wine_df["chlorides"].sum()*100
red_wine_clorides
# Out:
# 38.42385779829116

# %%
wine_df["type"].value_counts(normalize=True)*100
# Out:
# white    75.388641
# red      24.611359
# Name: type, dtype: float64

# %%
plt.figure(figsize=(6,4))
sns.barplot(data=wine_df,x="type",y="chlorides",errorbar=None)
plt.title("Bar plot for which type wine has more chlorides in wine",y=1.02)
plt.xlabel("type")
plt.show()

# %% [markdown]
# Observations
#
# *   From above anlysis we can easly conclude that more salt present in red wine and less in white wine.
# *   Red wine sharing only 24.61% data but it has chlorides 38.42% present in wine

# %% [markdown]
# #Correlation b/w alcohol level and quality of wine

# %%
wine_df[["quality","alcohol"]].corr()
# Out:
#           quality   alcohol
# quality  1.000000  0.444319
# alcohol  0.444319  1.000000

# %%
#scatter plot for column "quality" & "alcohol"
sns.scatterplot(data=wine_df, x="quality", y="alcohol",color="gold")
# Out:
# <Axes: xlabel='quality', ylabel='alcohol'>

# %%
# RegPlot
sns.regplot(data=wine_df, x="quality", y="alcohol",scatter_kws={"color":'teal'},line_kws={"color":'red'})
# Out:
# <Axes: xlabel='quality', ylabel='alcohol'>

# %%
sns.barplot(data=wine_df,x="quality",y="alcohol")
# Out:
# <Axes: xlabel='quality', ylabel='alcohol'>

# %% [markdown]
# Observations
# *   From above observations it is cearly visible that if the level of alcohol content in wine increases the quality of wine also increasing
# *   Both alcohol level and quality of wine is positively correlated
# *   Bar plot helps to find that quality level 9 has more alcohol content in wine

# %% [markdown]
# #checking correleation b/w ph-level and quality of wine

# %%
#checking correlation
wine_df[["pH","quality"]].corr()
# Out:
#                pH   quality
# pH       1.000000  0.019366
# quality  0.019366  1.000000

# %%
sns.scatterplot(data=wine_df, x="quality", y="pH",color="gold")
# Out:
# <Axes: xlabel='quality', ylabel='pH'>

# %%
sns.barplot(data=wine_df,x="quality",y="pH")
# Out:
# <Axes: xlabel='quality', ylabel='pH'>

# %% [markdown]
# Observations
# *   From above observtions we can conclude that quality level 9 has more ph value means it is more acidic
# *   Above observation not prove any much valuable information, both columns are less correlated

# %%
wine_df.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# ...

# %% [markdown]
# from above observations we can find that columns citric acid ,density,sulphates,pH not providing any much sense information , going to drop these columns

# %%
#wine_df.drop(columns=["citric acid","density","sulphates"],inplace=True,axis=1)

# %%
wine_df.drop(columns=["pH"],inplace=True,axis=1)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## 1. Handling Duplicate data

# %%
wine_df.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density  sulphates  \
# 0      0.045                 45.0                 170.0   1.0010       0.45
# 1      0.049                 14.0                 132.0   0.9940       0.49
# 2      0.050                 30.0                  97.0   0.9951       0.44
# 3      0.058                 47.0                 186.0   0.9956       0.40
# 4      0.058                 47.0                 186.0   0.9956       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# ...

# %%
## Check shape of original data
len(wine_df)
# Out:
# 6497

# %%
wine_df.drop_duplicates(keep="first",inplace=True)

# %%
## Check shape after applying drop duplicates.

# %%
len(wine_df)
# Out:
# 5327

# %% [markdown]
# Observations
# *   No duplicates in data are available
# *   as lenght of the data or coumns numbers has no change

# %% [markdown]
# ## 2.  Handling Missing Values

# %%
## Applying isnull() function and find the sum of missing values in all columns.
wine_df.isnull().sum()
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %%
## Finding missing value in % form.

# %%
(wine_df.isnull().sum()/len(wine_df))*100
# Out:
# type                    0.000000
# fixed acidity           0.187723
# volatile acidity        0.150178
# citric acid             0.056317
# residual sugar          0.037545
# chlorides               0.037545
# free sulfur dioxide     0.000000
# total sulfur dioxide    0.000000
# density                 0.000000
# sulphates               0.075089
# alcohol                 0.000000
# quality                 0.000000
# dtype: float64

# %% [markdown]
# Observations
# *   From above observation we can see that fixed acidity has 10 nos of missing values
# *  Volatile acidity has 8 & citric acid has 3 residual sugar has 2 chlorides has also 2 missing values respectivelly.
# *   pH and sulphates has 9 & 4 missing values respectivelly.

# %%
## Substituting missing values by mean of the columns

# %% [markdown]
# subtituing missing values for column "fixed acidity"

# %%
wine_df["fixed acidity"].mean() #mean values for column
# Out:
# 7.21659770547301

# %%
wine_df["fixed acidity"].fillna(wine_df["fixed acidity"].mean(),inplace=True)

# %% [markdown]
# subtituting nan values for column "volatile acidity"

# %%
#Taking the mean value
wine_df["volatile acidity"].mean()
# Out:
# 0.344153036285016

# %%
#Filling the value
wine_df["volatile acidity"].fillna(wine_df["volatile acidity"].mean(),inplace=True)

# %% [markdown]
# Remaining columns which has nan values are very less we can use fillna with forword fill, to subtitute missing values

# %%
wine_df.fillna(method="ffill",inplace=True)#fillna for remaining columns

# %%
wine_df.isnull().sum()
# Out:
# type                    0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# Observations
# *   Now data has no missing values
# *   columns fixed acidity and volatile acidity and citric acid and pH subtituted with their respective means and other columns filled with fillna

# %% [markdown]
# ## 3. Handling Outliers

# %% [markdown]
# ###Handling Outliers for "fixed acidity" column

# %%
#Ploting boxplot
plt.figure(figsize=(4,2))
sns.boxplot(x=wine_df["fixed acidity"])
# Out:
# <Axes: xlabel='fixed acidity'>

# %%
q1=wine_df["fixed acidity"].quantile(0.25)
q2=wine_df["fixed acidity"].quantile(0.50)
q3=wine_df["fixed acidity"].quantile(0.75)
iqr=q3-q1

# %%
minimum_wisker=q1-1.5*iqr
minimum_wisker
# Out:
# 4.450000000000001

# %%
maximum_whisker=q3+1.5*iqr
maximum_whisker
# Out:
# 9.65

# %%
#After value of 10 there are so many outliers ,need to subtitute those outliers by median value
#Before value 4 need to subtitute by mdianvalue

# %%
wine_df.loc[wine_df["fixed acidity"] > 10,"fixed acidity"] = wine_df["fixed acidity"].median()

# %%
wine_df.loc[wine_df["fixed acidity"] < 4,"fixed acidity"] = wine_df["fixed acidity"].median()

# %%
plt.figure(figsize=(4,2))
sns.boxplot(x=wine_df["fixed acidity"])
# Out:
# <Axes: xlabel='fixed acidity'>

# %% [markdown]
# Observations
# *   The minimim whisker for fixed acidity column is 4.45 & maximum whisker is 9.5
# *   Avove the value of 10 in fixed acidity column ,subtituted with median value to handle the outlier
# *   Bellow thw value 4 in fixed acdity column ,subtituted with median value
# *   Now no outliers or extreme value present in fixed acidity column

# %% [markdown]
# #Handling outlier for "residual sugar" column

# %%
#ploting boxplot
plt.figure(figsize=(4,2))
sns.boxplot(x=wine_df["residual sugar"])
# Out:
# <Axes: xlabel='residual sugar'>

# %%
q1=wine_df["residual sugar"].quantile(0.25)
q2=wine_df["residual sugar"].quantile(0.50)
q3=wine_df["residual sugar"].quantile(0.75)
iqr=q3-q1

# %%
minimum_wisker=q1-1.5*iqr
minimum_wisker
# Out:
# -6.750000000000001

# %%
maximum_wisker=q3+1.5*iqr
maximum_wisker
# Out:
# 16.05

# %%
#subtituting the value which is above 25
wine_df.loc[wine_df["residual sugar"] >25,"residual sugar"] =wine_df["residual sugar"].median()

# %%
plt.figure(figsize=(4,2))
sns.boxplot(x=wine_df["residual sugar"])
# Out:
# <Axes: xlabel='residual sugar'>

# %% [markdown]
# Observations
# *   The minimim whisker for residual suagar column is 0 & maximum whisker is 20.04
# *   Avove the value of 25 in residual suagar column ,subtituted with maximum whisker value to handle the outlier
# Now no outliers or extreme value present in residual suagar column

# %% [markdown]
# ###Handling outlier for "free sulfur dioxide" column

# %%
#plotting boxplot
plt.figure(figsize=(4,2))
sns.boxplot(x=wine_df["free sulfur dioxide"])
# Out:
# <Axes: xlabel='free sulfur dioxide'>

# %%
q1=wine_df["free sulfur dioxide"].quantile(0.25)
q2=wine_df["free sulfur dioxide"].quantile(0.50)
q3=wine_df["free sulfur dioxide"].quantile(0.75)
iqr=q3-q1

# %%
minimum_wisker=q1-1.5*iqr
minimum_wisker
# Out:
# -21.5

# %%
maximum_wisker=q3+1.5*iqr
maximum_wisker
# Out:
# 78.5

# %%
#subtituting the value which is above 80
wine_df.loc[wine_df["free sulfur dioxide"] >80,"free sulfur dioxide"] = wine_df["free sulfur dioxide"].median()

# %%
#Again plotting boxplot
plt.figure(figsize=(4,2))
sns.boxplot(x=wine_df["free sulfur dioxide"])
# Out:
# <Axes: xlabel='free sulfur dioxide'>

# %% [markdown]
# Observations
# *   The minimim whisker for "free sulfur dioxide" column is 78.5 & maximum whisker is 0.
# *   Avove the value of 80 in "free sulfur dioxide" ,subtituted with maximum whisker value to handle the outlier
# *   Now no outliers or extreme value present in free sulfur dioxide column

# %% [markdown]
# #Handling outliers for column "total sulfur dioxide"

# %%
#Ploting boxplot
plt.figure(figsize=(4,2))
sns.boxplot(x=wine_df["total sulfur dioxide"])
# Out:
# <Axes: xlabel='total sulfur dioxide'>

# %%
q1=wine_df["total sulfur dioxide"].quantile(0.25)
q2=wine_df["total sulfur dioxide"].quantile(0.50)
q3=wine_df["total sulfur dioxide"].quantile(0.75)
iqr=q3-q1

# %%
minimum_wisker=q1-1.5*iqr
minimum_wisker
# Out:
# -43.5

# %%
maximum_wisker=q3+1.5*iqr
maximum_wisker
# Out:
# 272.5

# %%
#Subtituting the value
wine_df.loc[wine_df["total sulfur dioxide"] > 290,"total sulfur dioxide"]=wine_df["total sulfur dioxide"].median()

# %%
#Ploting again
plt.figure(figsize=(4,2))
sns.boxplot(x=wine_df["total sulfur dioxide"])
# Out:
# <Axes: xlabel='total sulfur dioxide'>

# %% [markdown]
# Observations
# *   The minimim whisker for "total sulfur dioxide" column is 271 & maximum whisker is 0.
# * Avove the value of 290 in "total sulfur dioxide" ,subtituted with maximum whisker value to handle the outlier
# *   Now no outliers or extreme value present in total sulfur dioxide column

# %%
wine_df.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 6  white            6.2              0.32         0.16             7.0
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density  sulphates  \
# 0      0.045                 45.0                 170.0   1.0010       0.45
# 1      0.049                 14.0                 132.0   0.9940       0.49
# 2      0.050                 30.0                  97.0   0.9951       0.44
# 3      0.058                 47.0                 186.0   0.9956       0.40
# 6      0.045                 30.0                 136.0   0.9949       0.47
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# ...

# %% [markdown]
# ## 4. Handling Categoirical Values

# %%
#type column has categorical values need yo covert on numerical values

# %%
wine_df = pd.get_dummies(wine_df, columns=["type"], drop_first=True)

# %%
wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0             0.270         0.36            20.7      0.045
# 1               6.3             0.300         0.34             1.6      0.049
# 2               8.1             0.280         0.40             6.9      0.050
# 3               7.2             0.230         0.32             8.5      0.058
# 6               6.2             0.320         0.16             7.0      0.045
# ...             ...               ...          ...             ...        ...
# 6491            6.8             0.620         0.08             1.9      0.068
# 6492            6.2             0.600         0.08             2.0      0.090
# 6493            5.9             0.550         0.10             2.2      0.062
# 6495            5.9             0.645         0.12             2.0      0.075
# 6496            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# Observations
#
#
# *   We have column type has two unique values Red and White , which indicates the type of wine
# *   As ths is the nominal type categorical column ,convrted in numerical column where 1 indicates type of wine in each column

# %% [markdown]
# ## 5 . Handling Numerical values

# %%
wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 6            6.2              0.32         0.16             7.0      0.045
#
#    free sulfur dioxide  total sulfur dioxide  density  sulphates  alcohol  \
# 0                 45.0                 170.0   1.0010       0.45      8.8
# 1                 14.0                 132.0   0.9940       0.49      9.5
# 2                 30.0                  97.0   0.9951       0.44     10.1
# 3                 47.0                 186.0   0.9956       0.40      9.9
# 6                 30.0                 136.0   0.9949       0.47      9.6
#
#    quality  type_white
# 0        6           1
# ...

# %% [markdown]
# we have columns "free sulfur dioxide",	"total sulfur dioxide",	"alcohol","residual sugar","fixed acidity" need to handle

# %%
#checkig skeweness for each column

# %%
#Distribution plot for each columns
plt.figure(figsize=(4,2))
plt.title("density plot for fixed acidity")
sns.displot(x=wine_df["fixed acidity"],kind="kde")
plt.title("density plot for residual sugar")
plt.figure(figsize=(4,2))
sns.displot(x=wine_df["residual sugar"],kind="kde")
plt.title("alcohol")
plt.figure(figsize=(4,2))
sns.displot(x=wine_df["alcohol"],kind="kde")
plt.title("total sulfur dioxide")
plt.figure(figsize=(4,2))
sns.displot(x=wine_df["total sulfur dioxide"],kind="kde")
plt.title("density plot for free sulfur dioxide")
plt.figure(figsize=(4,2))
sns.displot(x=wine_df["free sulfur dioxide"],kind="kde")

# %%
#Checking skewness for each numerical column
print(wine_df["fixed acidity"].skew())
print(wine_df["residual sugar"].skew())
print(wine_df["alcohol"].skew())
print(wine_df["free sulfur dioxide"].skew())
print(wine_df["total sulfur dioxide"].skew())
# Out:
# 0.5954274816290609
# 1.2845381462839205
# 0.5457397424639072
# 0.4818816388218694
# -0.01600714438469896

# %% [markdown]
# Observations
# 1. clearly visible that four no of  the columns are not skewed and we can apply standard scaller to handle them "free_sulpher dioxide & total sulpher dioxide ,"alcohol", "fixed acidity "
# 2. Other one column are skewed as values are not lies b/w -0.5 to 0.5
# 3. We will apply minmax scaller to the columns  residual sugar

# %%
## If your data is not skwed and symmetrical apply standard scaler.

# %%
from sklearn.preprocessing import StandardScaler

# Standardize free sulpher dioxode","total sulpher dioxode","fixed acidity" & "alcohol"  columns
scaler = StandardScaler()
wine_df[["free sulfur dioxide", "total sulfur dioxide","fixed acidity","alcohol"]] = scaler.fit_transform(wine_df[[ "free sulfur dioxide", "total sulfur dioxide","fixed acidity","alcohol"]])
wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         -0.038027             0.270         0.36        0.877729      0.045
# 1         -0.764028             0.300         0.34        0.043668      0.049
# 2          1.102831             0.280         0.40        0.275109      0.050
# 3          0.169402             0.230         0.32        0.344978      0.058
# 6         -0.867742             0.320         0.16        0.279476      0.045
# ...             ...               ...          ...             ...        ...
# 6491      -0.245456             0.620         0.08        0.056769      0.068
# 6492      -0.867742             0.600         0.08        0.061135      0.090
# 6493      -1.178885             0.550         0.10        0.069869      0.062
# 6495      -1.178885             0.645         0.12        0.061135      0.075
# 6496      -1.075171             0.310         0.47        0.131004      0.067
#
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
## Standardize ' residual sugar colum
minmaxscaler = MinMaxScaler() 
wine_df[["residual sugar"]] = minmaxscaler.fit_transform(wine_df[["residual sugar"]])

# %% [markdown]
# #Observations
# *   columns  "free sulfur dioxide", "total sulfur dioxide", "alcohol","fixed acidity" are symmetrical columns
# *   Applied standardscaller to handel them and now data is ready for modeling part
# * Other column residual sugar skewed in nture so applied minmax scaler to handle the column
# *   Other columns like "quality" is in ordinal form and other columns are in a manner so we do not need to handle them

# %% [markdown]
# # Model Building

# %%
wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0      -0.038027              0.27         0.36        0.877729      0.045
# 1      -0.764028              0.30         0.34        0.043668      0.049
# 2       1.102831              0.28         0.40        0.275109      0.050
# 3       0.169402              0.23         0.32        0.344978      0.058
# 6      -0.867742              0.32         0.16        0.279476      0.045
#
#    free sulfur dioxide  total sulfur dioxide  density  sulphates   alcohol  \
# 0             0.944128              0.999425   1.0010       0.45 -1.474767
# 1            -0.944825              0.322777   0.9940       0.49 -0.884532
# 2             0.030118             -0.300451   0.9951       0.44 -0.378616
# 3             1.065995              1.284330   0.9956       0.40 -0.547254
# 6             0.030118              0.394003   0.9949       0.47 -0.800212
#
#    quality  type_white
# 0        6           1
# ...
